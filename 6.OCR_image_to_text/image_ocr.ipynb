# %%
import cv2
import pytesseract
import numpy as np
from PIL import ImageGrab
import time


pytesseract.pytesseract.tesseract_cmd = 'C:\Program Files\Tesseract-OCR\\tesseract.exe'
img = cv2.imread('scr.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
pytesseract

height, width,_ = img.shape
boxes = pytesseract.image_to_boxes(img)
for b in boxes.splitlines():
    print(b)
    b = b.split(' ')
    print(b)
    x, y, w, h = int(b[1]), int(b[2]), int(b[3]), int(b[4])
    cv2.rectangle(img, (x, height- y), (w, height- h), (0, 255, 0), 1)
    cv2.putText(img,b[0],(x,height- y+25),cv2.FONT_HERSHEY_SIMPLEX,1,(0,255,0),2)

print(pytesseract.image_to_string(img))
cv2.imshow('Img_to_text', img)
cv2.waitKey(0)
# Out:
# H 461 325 505 377 0
# ['H', '461', '325', '505', '377', '0']
# o 513 324 550 362 0
# ['o', '513', '324', '550', '362', '0']
# w 552 325 609 362 0
# ['w', '552', '325', '609', '362', '0']
# t 627 324 652 373 0
# ['t', '627', '324', '652', '373', '0']
# o 655 324 692 362 0
# ['o', '655', '324', '692', '362', '0']
# R 716 325 757 377 0
# ['R', '716', '325', '757', '377', '0']
# e 759 324 794 362 0
# ['e', '759', '324', '794', '362', '0']
# c 798 324 829 362 0
# ['c', '798', '324', '829', '362', '0']
# o 832 324 869 362 0
# ['o', '832', '324', '869', '362', '0']
# r 875 325 898 363 0
# ['r', '875', '325', '898', '363', '0']
# d 900 324 934 378 0
# ['d', '900', '324', '934', '378', '0']
# S 957 324 992 377 0
# ['S', '957', '324', '992', '377', '0']
# c 996 324 1028 362 0
# ['c', '996', '324', '1028', '362', '0']
# r 1033 325 1056 363 0
# ['r', '1033', '325', '1056', '363', '0']
# e 1058 324 1092 362 0
# ['e', '1058', '324', '1092', '362', '0']
# e 1096 324 1130 362 0
# ['e', '1096', '324', '1130', '362', '0']
# n 1136 325 1169 362 0
# ['n', '1136', '325', '1169', '362', '0']
# O 483 220 512 251 0
# ['O', '483', '220', '512', '251', '0']
# N 516 220 544 251 0
# ['N', '516', '220', '544', '251', '0']
# A 554 220 582 251 0
# ['A', '554', '220', '582', '251', '0']
# N 586 220 614 251 0
# ['N', '586', '220', '614', '251', '0']
# Y 619 220 644 251 0
# ['Y', '619', '220', '644', '251', '0']
# A 652 220 680 251 0
# ['A', '652', '220', '680', '251', '0']
# N 684 220 712 251 0
# ['N', '684', '220', '712', '251', '0']
# D 715 220 743 251 0
# ['D', '715', '220', '743', '251', '0']
# R 746 220 769 251 0
# ['R', '746', '220', '769', '251', '0']
# O 774 219 803 251 0
# ['O', '774', '219', '803', '251', '0']
# I 807 220 816 251 0
# ['I', '807', '220', '816', '251', '0']
# D 820 220 848 251 0
# ['D', '820', '220', '848', '251', '0']
# S 860 220 881 251 0
# ['S', '860', '220', '881', '251', '0']
# M 884 220 919 251 0
# ['M', '884', '220', '919', '251', '0']
# A 920 220 947 251 0
# ['A', '920', '220', '947', '251', '0']
# R 952 220 974 251 0
# ['R', '952', '220', '974', '251', '0']
# T 980 220 1003 251 0
# ['T', '980', '220', '1003', '251', '0']
# P 1004 220 1027 251 0
# ['P', '1004', '220', '1027', '251', '0']
# H 1030 220 1058 251 0
# ['H', '1030', '220', '1058', '251', '0']
# O 1061 219 1091 251 0
# ['O', '1061', '219', '1091', '251', '0']
# N 1094 220 1122 251 0
# ['N', '1094', '220', '1122', '251', '0']
# E 1125 220 1147 251 0
# ['E', '1125', '220', '1147', '251', '0']
# ~ 82 128 426 472 0
# ['~', '82', '128', '426', '472', '0']
# -1
